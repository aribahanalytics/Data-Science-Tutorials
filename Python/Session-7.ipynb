# %%
#loc

#selecting rows by label/index
#selcting by conditions

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Data/uk-500.csv')

# %%
data.head()
# Out:
#   FirstName    LastName                  Company            Address  \
# 0   Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1      Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2    France     Andrade      Elliott, John W Esq       8 Moor Place
# 3   Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4    Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              City           County  PostCode    Telephone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#      Telephone2                       Email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# ...

# %%
data.head(2:10)
# Out:
#   File "<ipython-input-7-01f713f77d29>", line 1
#     data.head(2:10)
#                ^
# SyntaxError: invalid syntax

# %%
data.head(10)
# Out:
#   FirstName    LastName                        Company               Address  \
# 0   Aleshia  Tomkiewicz        Alan D Rosenburg Cpa Pc          14 Taylor St
# 1      Evan   Zigomalas             Cap Gemini America           5 Binney St
# 2    France     Andrade            Elliott, John W Esq          8 Moor Place
# 3   Ulysses   Mcwalters                 Mcmahan, Ben L         505 Exeter Rd
# 4    Tyisha      Veness                 Champagne Room     5396 Forth Street
# 5      Eric       Rampy        Thompson, Michael C Esq          9472 Lind St
# 6      Marg    Grasmick  Wrangle Hill Auto Auct & Slvg      7457 Cowl St #70
# 7   Laquita       Hisaw          In Communications Inc  20 Gloucester Pl #96
# 8      Lura    Manzella                Bizerba Usa Inc      929 Augustine St
# 9    Yuette      Klapec                      Max Video  45 Bradfield St #166
#
#                              City                 County  PostCode  \
# ...

# %%
data.iloc[:,4]
# Out:
# 0                   St. Stephens Ward
# 1                          Abbey Ward
# 2      East Southbourne and Tuckton W
# 3                  Hawerby cum Beesby
# 4          Greets Green and Lyng Ward
# 5                          Desborough
# 6                        Bargate Ward
# 7                        Chirton Ward
# 8                    Staple Hill Ward
# 9                             Parwich
# 10                         Wilmington
# 11               Loundsley Green Ward
# 12                           Dee Ward
# 13     Broxburn, Uphall and Winchburg
# 14                  Weston-Super-Mare
# 15                          Carbrooke
# 16                         New Milton
# 17                            Parkham
# 18                       Darnall Ward
# 19                            Marldon
# 20                Prestatyn Community
# 21     Lye and Stourbridge North Ward
# 22                         Warlingham
# 23                            Newport
# 24                         Chichester
# ...

# %%
data.set_index("LastName", inplace=True)
data.head()
# Out:
#            FirstName                  Company            Address  \
# LastName
# Tomkiewicz   Aleshia  Alan D Rosenburg Cpa Pc       14 Taylor St
# Zigomalas       Evan       Cap Gemini America        5 Binney St
# Andrade       France      Elliott, John W Esq       8 Moor Place
# Mcwalters    Ulysses           Mcmahan, Ben L      505 Exeter Rd
# Veness        Tyisha           Champagne Room  5396 Forth Street
#
#                                       City           County  PostCode  \
# LastName
# Tomkiewicz               St. Stephens Ward             Kent   CT2 7PP
# Zigomalas                       Abbey Ward  Buckinghamshire  HP11 2AX
# Andrade     East Southbourne and Tuckton W      Bournemouth   BH6 3BE
# Mcwalters               Hawerby cum Beesby     Lincolnshire  DN36 5RP
# Veness          Greets Green and Lyng Ward    West Midlands   B70 9DT
#
#               Telephone1    Telephone2                       Email  \
# LastName
# ...

# %%
data.loc['Andrade']
# Out:
# FirstName                               France
# Company                    Elliott, John W Esq
# Address                           8 Moor Place
# City            East Southbourne and Tuckton W
# County                             Bournemouth
# PostCode                               BH6 3BE
# Telephone1                        01347-368222
# Telephone2                        01935-821636
# Email               france.andrade@hotmail.com
# Web           http://www.elliottjohnwesq.co.uk
# Name: Andrade, dtype: object

# %%
data.loc[['Andrade', 'Veness' ]]
# Out:
#          FirstName              Company            Address  \
# LastName
# Andrade     France  Elliott, John W Esq       8 Moor Place
# Veness      Tyisha       Champagne Room  5396 Forth Street
#
#                                     City         County PostCode  \
# LastName
# Andrade   East Southbourne and Tuckton W    Bournemouth  BH6 3BE
# Veness        Greets Green and Lyng Ward  West Midlands  B70 9DT
#
#             Telephone1    Telephone2                       Email  \
# LastName
# Andrade   01347-368222  01935-821636  france.andrade@hotmail.com
# Veness    01547-429341  01290-367248   tyisha.veness@hotmail.com
#
#                                        Web
# LastName
# Andrade   http://www.elliottjohnwesq.co.uk
# Veness      http://www.champagneroom.co.uk

# %%
data.loc[['Andrade', 'Veness'], ['FirstName', 'Company']]
# Out:
#          FirstName              Company
# LastName
# Andrade     France  Elliott, John W Esq
# Veness      Tyisha       Champagne Room

# %%
data.set_index('id', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\python\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5239)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5085)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20405)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20359)()
#
# KeyError: 'id'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
data.columns
# Out:
# Index(['FirstName', 'LastName', 'Company', 'Address', 'City', 'County',
#        'PostCode', 'Telephone1', 'Telephone2', 'Email', 'Web'],
#       dtype='object')

# %%
data.set_index('PostCode', inplace=True)

# %%
data.head()
# Out:
#          FirstName    LastName                  Company            Address  \
# PostCode
# CT2 7PP    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# HP11 2AX      Evan   Zigomalas       Cap Gemini America        5 Binney St
# BH6 3BE     France     Andrade      Elliott, John W Esq       8 Moor Place
# DN36 5RP   Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# B70 9DT     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                                     City           County    Telephone1  \
# PostCode
# CT2 7PP                St. Stephens Ward             Kent  01835-703597
# HP11 2AX                      Abbey Ward  Buckinghamshire  01937-864715
# BH6 3BE   East Southbourne and Tuckton W      Bournemouth  01347-368222
# DN36 5RP              Hawerby cum Beesby     Lincolnshire  01912-771311
# B70 9DT       Greets Green and Lyng Ward    West Midlands  01547-429341
#
#             Telephone2                       Email  \
# ...

# %%
data.loc['CT2 7PP']
# Out:
# FirstName                                  Aleshia
# LastName                                Tomkiewicz
# Company                    Alan D Rosenburg Cpa Pc
# Address                               14 Taylor St
# City                             St. Stephens Ward
# County                                        Kent
# Telephone1                            01835-703597
# Telephone2                            01944-369967
# Email                      atomkiewicz@hotmail.com
# Web           http://www.alandrosenburgcpapc.co.uk
# Name: CT2 7PP, dtype: object

# %%
data.loc[data['FirstName'] == 'France']
# Out:
#          FirstName LastName              Company       Address  \
# PostCode
# BH6 3BE     France  Andrade  Elliott, John W Esq  8 Moor Place
#
#                                     City       County    Telephone1  \
# PostCode
# BH6 3BE   East Southbourne and Tuckton W  Bournemouth  01347-368222
#
#             Telephone2                       Email  \
# PostCode
# BH6 3BE   01935-821636  france.andrade@hotmail.com
#
#                                        Web
# PostCode
# BH6 3BE   http://www.elliottjohnwesq.co.uk

# %%
data.loc[data['FirstName'] == 'France', ['City']]
# Out:
#                                     City
# PostCode
# BH6 3BE   East Southbourne and Tuckton W

# %%
data.loc[data['FirstName'] == 'France', ['City', 'County']]
# Out:
#                                     City       County
# PostCode
# BH6 3BE   East Southbourne and Tuckton W  Bournemouth

# %%
data.loc[data['Email'].str.endswith('hotmail.com')]
# Out:
#            FirstName       LastName                         Company  \
# PostCode
# CT2 7PP      Aleshia     Tomkiewicz         Alan D Rosenburg Cpa Pc
# BH6 3BE       France        Andrade             Elliott, John W Esq
# DN36 5RP     Ulysses      Mcwalters                  Mcmahan, Ben L
# B70 9DT       Tyisha         Veness                  Champagne Room
# SO14 3TY        Marg       Grasmick   Wrangle Hill Auto Auct & Slvg
# BS16 4LL        Lura       Manzella                 Bizerba Usa Inc
# EX39 5DJ      Dewitt          Julio            Rittenhouse Motor Co
# PO19 1RH        Tess          Sitra                     Smart Signs
# HU8 9PZ       German         Zelaya   Jackson & Heit Machine Co Inc
# SY11 4PH        Luis            Ear        Wa Inst For Plcy Studies
# DL3 0JF        Ciara        Cobbley                   Wmgl 101.7 Fm
# BN12 6PR     Alethea          Mould            Hughlett, Henry T Jr
# WS9 8UR      Vicente        Rawicki   B & S Tool And Cutter Svc Inc
# ...

# %%
data.loc[data['Email'].str.endswith('gmail.com')]
# Out:
#             FirstName    LastName                         Company  \
# PostCode
# HP11 2AX         Evan   Zigomalas              Cap Gemini America
# S40 4LY   Charlesetta         Erm                Cain, John M Esq
# DG8 7DE      Corrinne       Jaret               Sound Vision Corp
# B33 0NH         Karma      Quarto                 J C S Machinery
# DY11 9BW        Milly     Savidge       Bridgeway Plan For Health
# SN10 3DU    Margurite   Loperfido      Penrose Place Pharmacy Inc
# SO41 1DL       Melina    Orizabal        Sheraton Inn Ocean Front
# HP21 8PP         Tina     Clapham               Cooper Myers Y Co
# LS9 7JH         Luisa    Devereux                   Cash 4 Checks
# NG9 1AE          Alba     Mosseri        Schwartzbard, Gail L Esq
# SE14 6RQ       Dustin   Klingaman                  Welders Supply
# GU21 5QL    Margarett       Bairo            Reid, Carleton B Esq
# DN12 4JF          Sol      Cowser                   Omni Mandalay
# ...

# %%
data.loc[data['FirstName'].str.isin(['Frace', 'Tyisha', 'Eric'])]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-a19ebd40b265> in <module>()
# ----> 1 data.loc[data['FirstName'].str.isin(['Frace', 'Tyisha', 'Eric'])]
#
# AttributeError: 'StringMethods' object has no attribute 'isin'

# %%
data.loc[data['FirstName'].isin(['France', 'Tyisha', 'Eric'])]
# Out:
#          FirstName LastName                  Company            Address  \
# PostCode
# BH6 3BE     France  Andrade      Elliott, John W Esq       8 Moor Place
# B70 9DT     Tyisha   Veness           Champagne Room  5396 Forth Street
# NN14 2GH      Eric    Rampy  Thompson, Michael C Esq       9472 Lind St
#
#                                     City            County    Telephone1  \
# PostCode
# BH6 3BE   East Southbourne and Tuckton W       Bournemouth  01347-368222
# B70 9DT       Greets Green and Lyng Ward     West Midlands  01547-429341
# NN14 2GH                      Desborough  Northamptonshire  01969-886290
#
#             Telephone2                       Email  \
# PostCode
# BH6 3BE   01935-821636  france.andrade@hotmail.com
# B70 9DT   01290-367248   tyisha.veness@hotmail.com
# NN14 2GH  01545-817375          erampy@rampy.co.uk
#
#                                            Web
# PostCode
# BH6 3BE       http://www.elliottjohnwesq.co.uk
# ...

# %%
data.loc[data['FirstName'].isin(['France', 'Tyisha', 'Eric']), ['City', 'County']]
# Out:
#                                     City            County
# PostCode
# BH6 3BE   East Southbourne and Tuckton W       Bournemouth
# B70 9DT       Greets Green and Lyng Ward     West Midlands
# NN14 2GH                      Desborough  Northamptonshire

# %%
data.loc[data['FirstName'].isin(['France', 'Tyisha', 'Eric']), ['FirstName':'County']]
# Out:
#   File "<ipython-input-47-aed4e25e44d6>", line 1
#     data.loc[data['FirstName'].isin(['France', 'Tyisha', 'Eric']), ['FirstName':'County']]
#                                                                                ^
# SyntaxError: invalid syntax

# %%
data.loc[data['FirstName'].isin(['France', 'Tyisha', 'Eric']), 'FirstName':'County']
# Out:
#          FirstName LastName                  Company            Address  \
# PostCode
# BH6 3BE     France  Andrade      Elliott, John W Esq       8 Moor Place
# B70 9DT     Tyisha   Veness           Champagne Room  5396 Forth Street
# NN14 2GH      Eric    Rampy  Thompson, Michael C Esq       9472 Lind St
#
#                                     City            County
# PostCode
# BH6 3BE   East Southbourne and Tuckton W       Bournemouth
# B70 9DT       Greets Green and Lyng Ward     West Midlands
# NN14 2GH                      Desborough  Northamptonshire

# %%
iloc
loc

# %%
data.loc[data['Company'].apply(lambda x:len(x.split(' ')) == 4)]
# Out:
#             FirstName       LastName                        Company  \
# PostCode
# BH6 3BE        France        Andrade            Elliott, John W Esq
# NN14 2GH         Eric          Rampy        Thompson, Michael C Esq
# S40 4LY   Charlesetta            Erm               Cain, John M Esq
# IP25 6JQ      Michell      Throssell            Weiss Spirt & Guyer
# BH25 5DF        Edgar          Kanne          Crowan, Kenneth W Esq
# TQ3 1SA           Mee       Lapinski       Galloway Electric Co Inc
# LL19 9EG        Peter      Gutierres     Niagara Custombuilt Mfg Co
# CR6 9SW        Martha        Teplica         Curtin, Patricia M Esq
# PO30 5AL      Tamesha         Veigel            Wilhelm, James E Jr
# HS1 2PZ       Leonard         Kufner   Arctic Star Distributing Inc
# DN33 1AU     Svetlana         Tauras       Lensbower, Gregory L Esq
# B33 0NH         Karma         Quarto                J C S Machinery
# SG6 3LE          Reed      Weisinger           Berick, Joseph G Esq
# ...

# %%
t = data['Company']

# %%
t[1]
# Out:
# 'Cap Gemini America'

# %%
t[1].split(' ')
# Out:
# ['Cap', 'Gemini', 'America']

# %%
len(t[1].split(' '))
# Out:
# 3

# %%
len('Hughlett, Henry T Jr'.split(' '))
# Out:
# 4

# %%
'Hughlett, Henry T Jr'.split(' ')
# Out:
# ['Hughlett,', 'Henry', 'T', 'Jr']

# %%
'Hughlett, Henry T Jr'.split(',')
# Out:
# ['Hughlett', ' Henry T Jr']

# %%
data['Telephone1'].value_counts().head()
# Out:
# 01993-956208    1
# 01368-497445    1
# 01470-383444    1
# 01976-755279    1
# 01753-784273    1
# Name: Telephone1, dtype: int64

# %%
 data['Telephone1'].value_counts().head(10).plot()

# %%
 data['Telephone1'].value_counts().head(10).plot(kind='bar')
