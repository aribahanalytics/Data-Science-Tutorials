# %%
import matplotlib
print(matplotlib.__version__)
print(matplotlib.get_backend())

#use this command for Jupyter notebook backend
matplotlib.use('nbagg')
# Out:
# 2.0.2
# module://ipykernel.pylab.backend_inline

# %%
#Imports
import numpy as np
import matplotlib.pyplot as plt

# %%
#Figure
fig = plt.figure()

# %%
#Display the plot
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
#utility function for controlling the size of the figure
# Twice as tall as it is wide:
fig = plt.figure(figsize=plt.figaspect(2.0))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="399.9999913302337">

# %% [markdown]
# ### Axes

# %% [markdown]
# All plotting in done with respect to axis.

# %%
#create the figure object
fig = plt.figure()
#set the axis
ax = fig.add_subplot(111) #"224" means "2x2 grid, 4th subplot". 
ax.set(xlim=[0.5, 4.5], ylim=[-2, 8], title='An Example Axes',
       ylabel='Y-Axis', xlabel='X-Axis')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
fig = plt.figure()
ax = fig.add_subplot(111) #"224" means "2x2 grid, 4th subplot". 
ax.set(xlim=[0.5, 4.5], ylim=[-2, 8], title='An Example Plot',
       ylabel='Y', xlabel='X')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
fig = plt.figure()
fig.add_subplot(221)   #top left
fig.add_subplot(222)   #top right
fig.add_subplot(223)   #bottom left
fig.add_subplot(224)   #bottom right 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
fig = plt.figure()
fig.add_subplot(1, 2, 1)   #top and bottom left
fig.add_subplot(2, 2, 2)   #top right
fig.add_subplot(2, 2, 4)   #bottom right 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
fig = plt.figure()
ax = fig.add_subplot(111) # We'll explain the "111" later. Basically, 1 row and 1 column.
ax.set(xlim=[0.5, 4.5], ylim=[-2, 8], title='An Example Axes',
       ylabel='Y-Axis', xlabel='X-Axis')
#ax.set_xlim([0.5, 4.5])
#ax.set_ylim([-2, 8])
#ax.set_title('An Example Axes')
#ax.set_ylabel('Y-Axis')
#ax.set_xlabel('X-Axis')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
fig = plt.figure()
ax = fig.add_subplot(111) # We'll explain the "111" later. Basically, 1 row and 1 column.
#ax.set(xlim=[0.5, 4.5], ylim=[-2, 8], title='An Example Axes',
#       ylabel='Y-Axis', xlabel='X-Axis')
ax.set_xlim([0.5, 4.5])
ax.set_ylim([-2, 8])
ax.set_title('An Example Axes')
ax.set_ylabel('Y-Axis')
ax.set_xlabel('X-Axis')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot([1, 2, 3, 4], [10, 20, 25, 30], color='lightblue', linewidth=3)
ax.scatter([0.3, 3.8, 1.2, 2.5], [11, 25, 9, 26], color='darkgreen', marker='^')
ax.set_xlim(0.5, 4.5)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot([1, 2, 3, 4], [10, 20, 25, 30], color='lightblue', linewidth=3)
ax.scatter([0.3, 3.8, 1.2, 2.5], [11, 25, 9, 26], color='darkgreen', marker='^')
ax.scatter([1.3, 2.8, 2.2, 1.5], [10, 15, 10, 16], color='red', marker='^')

ax.set_xlim(0.5, 4.5)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
#1-D plots
#2-D plots
#3-D plots

# %%
#Figure
#axes

#1-D plots

ax.plot() #line/Markers
ax.scatter()
ax.bar()
polygons / Filled - stackplots

#2 - D plots

#contour

# %%
plt.subplots(nrows=2, ncols=2)
# Out:
# (<matplotlib.figure.Figure at 0x26510f5d390>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000265112E7A58>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000026511339D30>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x000002651137C710>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x00000265113CA860>]], dtype=object))

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

fig

# %%
type(axes)
# Out:
# numpy.ndarray

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000026511BBEEB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026511BFFFD0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000026511C52518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026511C92E10>]], dtype=object)

# %%
axes.shape
# Out:
# (2, 2)

# %%
axes.flat

# %%
b=axes.flat
b

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
axes[0,0].set(title='Upper Left')
axes[0,1].set(title='Upper Right')
axes[1,0].set(title='Lower Left')
axes[1,1].set(title='Lower Right')

# To iterate over all items in a multidimensional numpy array, use the `flat` attribute
for ax in axes.flat:
    # Remove all xticks and yticks...
    ax.set(xticks=[], yticks=[])
    
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# ## plt.subplots() is a function that returns a tuple containing a figure and axes object(s).

# %%
np.arange(5)
# Out:
# array([0, 1, 2, 3, 4])

# %%
np.random.randn(5)
# Out:
# array([-0.6387229 , -0.17805682,  2.42254968,  0.49323327,  0.80154023])

# %%
np.random.randn(5)
# Out:
# array([-0.6288177 , -0.23752669,  1.8607417 , -0.24499912, -2.44930198])

# %%
np.random.randn(5)
# Out:
# array([ 0.84135453,  0.68395848, -0.11134685, -0.94712204,  0.36837155])

# %%
np.random.seed(1)
np.random.randn(5)
# Out:
# array([ 1.62434536, -0.61175641, -0.52817175, -1.07296862,  0.86540763])

# %%
np.random.seed(1)
np.random.randn(5)
# Out:
# array([ 1.62434536, -0.61175641, -0.52817175, -1.07296862,  0.86540763])

# %%
np.random.seed(1)
x = np.arange(5)
y = np.random.randn(5)

# %%
plt.subplots(ncols=2)
# Out:
# (<matplotlib.figure.Figure at 0x26511ec86a0>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000265124E5198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002651252F438>], dtype=object))

# %%
plt.subplots()
# Out:
# (<matplotlib.figure.Figure at 0x2651295b748>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x26511d86080>)

# %%
np.random.seed(1)
x = np.arange(5)
y = np.random.randn(5)

fig, axes = plt.subplots(ncols=2, figsize=plt.figaspect(1./2))

vert_bars = axes[0].bar(x, y, color='lightblue', align='center')
horiz_bars = axes[1].barh(x, y, color='lightblue', align='center')

# I'll also introduce axhline & axvline to draw a line all the way across the axes
# This can be a quick-n-easy way to draw an axis "spine".
axes[0].axhline(0, color='gray', linewidth=2)
axes[1].axvline(0, color='gray', linewidth=2)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="959.9999791925608">

# %%
y
# Out:
# array([ 1.62434536, -0.61175641, -0.52817175, -1.07296862,  0.86540763])

# %%
fig, ax = plt.subplots()
vert_bars = ax.bar(x, y, color='lightblue', align='center')

# We could have also done this with two separate calls to `ax.bar` and numpy boolean indexing.
for bar, height in zip(vert_bars, y):
    if height < 0:
        bar.set(edgecolor='darkred', color='salmon', linewidth=3)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
np.random.randn(100)
# Out:
# array([-2.3015387 ,  1.74481176, -0.7612069 ,  0.3190391 , -0.24937038,
#         1.46210794, -2.06014071, -0.3224172 , -0.38405435,  1.13376944,
#        -1.09989127, -0.17242821, -0.87785842,  0.04221375,  0.58281521,
#        -1.10061918,  1.14472371,  0.90159072,  0.50249434,  0.90085595,
#        -0.68372786, -0.12289023, -0.93576943, -0.26788808,  0.53035547,
#        -0.69166075, -0.39675353, -0.6871727 , -0.84520564, -0.67124613,
#        -0.0126646 , -1.11731035,  0.2344157 ,  1.65980218,  0.74204416,
#        -0.19183555, -0.88762896, -0.74715829,  1.6924546 ,  0.05080775,
#        -0.63699565,  0.19091548,  2.10025514,  0.12015895,  0.61720311,
#         0.30017032, -0.35224985, -1.1425182 , -0.34934272, -0.20889423,
#         0.58662319,  0.83898341,  0.93110208,  0.28558733,  0.88514116,
#   -1.77964545  -2.55480706  -1.28105113   0.68605061  -1.17193125
#    0.06423278   1.69188353   2.02989523   0.8306272    1.69397252
#    1.51305221   0.90913159  -0.32092655   0.22961095   1.02241781
#    0.39888708   0.91946342  -0.22487797   0.57698306   0.62355036
#    0.43698059   0.33523472   1.20412087   1.95453251   2.48399784
#    2.62169905   2.69952017   3.31790044   3.550395     4.2329464
#    3.92282963   1.48799187   2.52681647   4.71379611   5.15516056
#    5.05500532   4.91856058   4.79950639   4.8169158    3.69489707
#    3.17780261   2.18077579   2.42957495   2.1329338    2.62814512
#    2.45344196   3.43977715   3.65331105   5.84401078   3.94764986
#    3.30073317   4.20222006   6.73054577   6.48191099   6.52557998
#    6.29926574   7.63072285   7.34341499   8.02348483   7.70368323
#    6.43112447   6.74467219   7.24785701   8.54108289   8.43063586
#    7.8132738    8.3760349    8.61677199   8.89743707   8.82432436
#    9.98466293  10.35415565  12.25881436  13.36987106  14.02892085
#   12.40148251  13.00380179  13.42408399  14.23503567  15.27947776]

# %%
np.linspace(0, 10, 100)
# Out:
# array([  0.        ,   0.1010101 ,   0.2020202 ,   0.3030303 ,
#          0.4040404 ,   0.50505051,   0.60606061,   0.70707071,
#          0.80808081,   0.90909091,   1.01010101,   1.11111111,
#          1.21212121,   1.31313131,   1.41414141,   1.51515152,
#          1.61616162,   1.71717172,   1.81818182,   1.91919192,
#          2.02020202,   2.12121212,   2.22222222,   2.32323232,
#          2.42424242,   2.52525253,   2.62626263,   2.72727273,
#          2.82828283,   2.92929293,   3.03030303,   3.13131313,
#          3.23232323,   3.33333333,   3.43434343,   3.53535354,
#          3.63636364,   3.73737374,   3.83838384,   3.93939394,
#          4.04040404,   4.14141414,   4.24242424,   4.34343434,
#          4.44444444,   4.54545455,   4.64646465,   4.74747475,
#          4.84848485,   4.94949495,   5.05050505,   5.15151515,
#          5.25252525,   5.35353535,   5.45454545,   5.55555556,
#          5.65656566,   5.75757576,   5.85858586,   5.95959596,
#          6.06060606,   6.16161616,   6.26262626,   6.36363636,
#          6.46464646,   6.56565657,   6.66666667,   6.76767677,
#          6.86868687,   6.96969697,   7.07070707,   7.17171717,
#          7.27272727,   7.37373737,   7.47474747,   7.57575758,
#          7.67676768,   7.77777778,   7.87878788,   7.97979798,
#          8.08080808,   8.18181818,   8.28282828,   8.38383838,
#          8.48484848,   8.58585859,   8.68686869,   8.78787879,
#          8.88888889,   8.98989899,   9.09090909,   9.19191919,
#          9.29292929,   9.39393939,   9.49494949,   9.5959596 ,
#          9.6969697 ,   9.7979798 ,   9.8989899 ,  10.        ])

# %%
np.random.seed(1)
y = np.random.randn(100).cumsum()
x = np.linspace(0, 10, 100)

fig, ax = plt.subplots()
ax.fill_between(x, y, color='lightblue')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
np.random.seed(1)
y = np.random.randn(1000).cumsum()
x = np.linspace(0, 10, 1000)

fig, ax = plt.subplots()
ax.fill_between(x, y, color='lightblue')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
x = np.linspace(0, 10, 200)
y1 = 2 * x + 1
y2 = 3 * x + 1.2
y_mean = 0.5 * x * np.cos(2*x) + 2.5 * x + 1.1

fig, ax = plt.subplots()

# Plot the envelope with `fill_between`
ax.fill_between(x, y1, y2, color='yellow')

# Plot the "centerline" with `plot`
ax.plot(x, y_mean, color='black')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
x = np.linspace(0, 10, 200)
data_obj = {'x': x,
            'y1': 2 * x + 1,
            'y2': 3 * x + 1.2,
            'mean': 0.5 * x * np.cos(2*x) + 2.5 * x + 1.1}

fig, ax = plt.subplots()

# Plot the envelope with `fill_between`
ax.fill_between('x', 'y1', 'y2', color='yellow', data=data_obj)

# Plot the "centerline" with `plot`
ax.plot('x', 'mean', color='black', data=data_obj)

plt.show()
# Out:
# c:\python\lib\site-packages\matplotlib\pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
from matplotlib.cbook import get_sample_data
data = np.load(get_sample_data('axes_grid/bivariate_normal.npy'))

fig, ax = plt.subplots()
im = ax.imshow(data, cmap='seismic', interpolation='nearest')
fig.colorbar(im)
plt.show()
# Out:
# c:\python\lib\site-packages\matplotlib\pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
np.load(get_sample_data('axes_grid/bivariate_normal.npy'))
# Out:
# array([[  5.93115274e-06,   2.34581641e-05,   7.22562324e-05,
#           1.73333691e-04,   3.23829967e-04,   4.71169822e-04,
#           5.33905355e-04,   4.71169822e-04,   3.23829967e-04,
#           1.73333691e-04,   7.22562324e-05,   2.34581641e-05,
#           5.93115274e-06,   1.16791322e-06,   1.79105293e-07],
#        [  3.86759742e-05,   1.52966445e-04,   4.71169822e-04,
#           1.13027764e-03,   2.11163664e-03,   3.07241318e-03,
#           3.48150024e-03,   3.07241318e-03,   2.11163664e-03,
#           1.13027764e-03,   4.71169822e-04,   1.52966445e-04,
#           3.86759742e-05,   7.61575086e-06,   1.16791322e-06],
#        [  1.96412803e-04,   7.76827707e-04,   2.39279779e-03,
#           5.74002351e-03,   1.07237757e-02,   1.56030016e-02,
#           1.76805171e-02,   1.56030016e-02,   1.07237757e-02,
#           5.74002351e-03,   2.39279779e-03,   7.76827707e-04,
#           1.96412803e-04,   3.86759742e-05,   5.93115273e-06],
#        [  7.76827706e-04,   3.07241318e-03,   9.46369884e-03,
#           2.27022333e-02,   4.24133557e-02,   6.17110684e-02,
#           6.99278017e-02,   6.17110684e-02,   4.24133557e-02,
#           2.27022333e-02,   9.46369881e-03,   3.07241315e-03,
#           7.76827687e-04,   1.52966433e-04,   2.34581575e-05],
#        [  2.39279687e-03,   9.46369673e-03,   2.91502403e-02,
#           6.99277936e-02,   1.30642320e-01,   1.90083453e-01,
#           2.15392767e-01,   1.90083442e-01,   1.30642301e-01,
#           6.99277711e-02,   2.91502188e-02,   9.46367925e-03,
#           2.39278451e-03,   4.71161763e-04,   7.22518585e-05],
#        [  5.73979760e-03,   2.27017136e-02,   6.99267314e-02,
#           1.67746104e-01,   3.13391413e-01,   4.55981750e-01,
#           5.16694117e-01,   4.55979066e-01,   3.13386756e-01,
#           1.67740595e-01,   6.99214693e-02,   2.26974368e-02,
#           5.73677235e-03,   1.12830572e-03,   1.72263432e-04],
#        [  1.07034407e-02,   4.23665653e-02,   1.30545991e-01,
#           3.13217157e-01,   5.85205655e-01,   8.51463249e-01,
#           9.64753502e-01,   8.51221618e-01,   5.84786441e-01,
#           3.12721261e-01,   1.30072309e-01,   4.19815824e-02,
#           1.04311156e-02,   1.93412933e-03,   2.27488324e-04],
#        [  1.49295978e-02,   6.01615826e-02,   1.86893076e-01,
#           4.50108312e-01,   8.42203451e-01,   1.22520158e+00,
#           1.38566084e+00,   1.21719987e+00,   8.28320999e-01,
#           4.33686476e-01,   1.71206871e-01,   4.74127008e-02,
#           5.91143107e-03,  -2.80582148e-03,  -2.71922723e-03],
#        [  9.47677979e-03,   5.10511999e-02,   1.76525800e-01,
#           4.45088891e-01,   8.47256027e-01,   1.23034767e+00,
#           1.36158534e+00,   1.13286697e+00,   6.78133136e-01,
#           2.45029980e-01,  -1.45712946e-02,  -1.04261975e-01,
#          -1.00386982e-01,  -6.81300580e-02,  -3.83330875e-02],
#        [ -2.11635983e-02,  -2.28879916e-02,   1.58936955e-02,
#           1.35045808e-01,   3.22753201e-01,   4.58835523e-01,
#           3.73909905e-01,   2.19573694e-02,  -4.35203013e-01,
#          -7.61556027e-01,  -8.40544065e-01,  -7.18953352e-01,
#          -5.13538820e-01,  -3.17868325e-01,  -1.73718607e-01],
#        [ -4.98940996e-02,  -9.70669141e-02,  -1.56548058e-01,
#          -2.15747157e-01,  -2.86909061e-01,  -4.35203013e-01,
#          -7.33894018e-01,  -1.15549332e+00,  -1.53656759e+00,
#          -1.69399367e+00,  -1.56857521e+00,  -1.24468468e+00,
#          -8.61683600e-01,  -5.27030185e-01,  -2.86866561e-01],
#        [ -3.10265764e-02,  -6.18968267e-02,  -1.04261975e-01,
#          -1.53192662e-01,  -2.15747157e-01,  -3.24677874e-01,
#          -5.13927088e-01,  -7.61556027e-01,  -9.73703370e-01,
#          -1.04979450e+00,  -9.60699736e-01,  -7.57962187e-01,
#          -5.23401798e-01,  -3.19810460e-01,  -1.74016443e-01],
#        [ -5.81093954e-03,  -9.41290296e-03,  -9.71674822e-03,
#          -1.68375655e-03,   1.25748335e-02,   1.58936955e-02,
#          -1.45712946e-02,  -8.15869968e-02,  -1.56548058e-01,
#          -2.01742668e-01,  -2.00813843e-01,  -1.64726078e-01,
#          -1.15674702e-01,  -7.11403884e-02,  -3.87947366e-02],
#        [  1.03423940e-04,   1.52292735e-03,   6.27330179e-03,
#           1.68239987e-02,   3.27217852e-02,   4.74127008e-02,
#           5.10511999e-02,   3.94109983e-02,   1.88393329e-02,
#           4.02163249e-04,  -9.41290296e-03,  -1.12259544e-02,
#          -8.91474281e-03,  -5.72526822e-03,  -3.16693889e-03],
#        [  1.76077772e-04,   7.30037289e-04,   2.29645615e-03,
#           5.56251620e-03,   1.04311156e-02,   1.51712283e-02,
#           1.71104931e-02,   1.49295978e-02,   1.00119019e-02,
#           5.06661974e-03,   1.82277381e-03,   3.45054418e-04,
#          -9.62472675e-05,  -1.38831332e-04,  -9.04104904e-05]])

# %%
get_sample_data('axes_grid/bivariate_normal.npy')
# Out:
# <_io.BufferedReader name='c:\\python\\lib\\site-packages\\matplotlib\\mpl-data\\sample_data\\axes_grid/bivariate_normal.npy'>

# %%
fig, ax = plt.subplots()
im = ax.imshow(data, cmap='gist_earth', interpolation='nearest',
               vmin=-2, vmax=2)
fig.colorbar(im)
plt.show()
# Out:
# c:\python\lib\site-packages\matplotlib\pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
fig, ax = plt.subplots(nrows=1, ncols=2)
print(ax.shape)
# Out:
# c:\python\lib\site-packages\matplotlib\pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# (2,)

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=plt.figaspect(0.5))

ax1.plot([-10, -5, 0, 5, 10, 15], [-1.2, 2, 3.5, -0.3, -4, 1])
ax2.scatter([-10, -5, 0, 5, 10, 15], [-1.2, 2, 3.5, -0.3, -4, 1])

plt.show()
# Out:
# c:\python\lib\site-packages\matplotlib\pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,..." width="959.9999791925608">

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=plt.figaspect(0.5))

ax1.plot([-10, -5, 0, 5, 10, 15], [-1.2, 2, 3.5, -0.3, -4, 1])
ax2.scatter([-10, -5, 0, 5, 10, 15], [-1.2, 2, 3.5, -0.3, -4, 1])

ax1.margins(x=0.0, y=0.1) # 10% padding in the y-direction only
ax2.margins(0.05) # 5% padding in all directions

plt.show()
# Out:
# c:\python\lib\site-packages\matplotlib\pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="959.9999791925608">

# %%
fig, axes = plt.subplots(nrows=3)

for ax in axes:
    ax.plot([-10, -5, 0, 5, 10, 15], [-1.2, 2, 3.5, -0.3, -4, 1])

ax1.margins(x=0.0, y=0.1) # 10% padding in the y-direction only
ax2.margins(0.05) # 5% padding in all directions
    
axes[0].set_title('Normal Autoscaling', y=0.7, x=0.8)

axes[1].set_title('ax.axis("tight")', y=0.7, x=0.8)
axes[1].axis('tight')

axes[2].set_title('ax.axis("equal")', y=0.7, x=0.8)
axes[2].axis('equal')

plt.show()
# Out:
# c:\python\lib\site-packages\matplotlib\pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
# Good -- setting limits after plotting is done
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=plt.figaspect(0.5))
ax1.plot([-10, -5, 0, 5, 10, 15], [-1.2, 2, 3.5, -0.3, -4, 1])
ax2.scatter([-10, -5, 0, 5, 10, 15], [-1.2, 2, 3.5, -0.3, -4, 1])
ax1.set_ylim(bottom=-10)
ax2.set_xlim(right=25)
plt.show()
# Out:
# c:\python\lib\site-packages\matplotlib\pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,..." width="959.9999791925608">

# %%
# Bad -- Setting limits before plotting is done
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=plt.figaspect(0.5))
ax1.set_ylim(bottom=-10)
ax2.set_xlim(right=25)
ax1.plot([-10, -5, 0, 5, 10, 15], [-1.2, 2, 3.5, -0.3, -4, 1])
ax2.scatter([-10, -5, 0, 5, 10, 15], [-1.2, 2, 3.5, -0.3, -4, 1])
plt.show()
# Out:
# c:\python\lib\site-packages\matplotlib\pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,..." width="959.9999791925608">

# %%
#Bad

fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4], [10, 20, 25, 30], label='Philadelphia')
ax.plot([1, 2, 3, 4], [30, 23, 13, 4], label='Boston')
ax.set(ylabel='Temperature (deg C)', xlabel='Time', title='A tale of two cities')
ax.legend()
plt.show()
# Out:
# c:\python\lib\site-packages\matplotlib\pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4], [10, 20, 25, 30], label='Philadelphia')
ax.plot([1, 2, 3, 4], [30, 23, 13, 4], label='Boston')
ax.set(ylabel='Temperature (deg C)', xlabel='Time', title='A tale of two cities')
ax.legend(loc='left')
plt.show()
# Out:
# c:\python\lib\site-packages\matplotlib\pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# c:\python\lib\site-packages\matplotlib\legend.py:326: UserWarning: Unrecognized location "left". Falling back on "best"; valid locations are
# 	upper center
# 	lower center
# 	lower right
# 	upper left
# 	right
# 	best
# 	center right
# 	center
# 	lower left
# 	center left
# 	upper right
#
#   six.iterkeys(self.codes))))
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
fig, ax = plt.subplots(1, 1)
ax.bar([1, 2, 3, 4], [10, 20, 25, 30], label="Foobar", align='center', color='lightblue')
ax.plot([1, 2, 3, 4], [10, 20, 25, 30], label="_nolegend_", marker='o', color='darkred')
ax.legend(loc='best')
plt.show()
# Out:
# c:\python\lib\site-packages\matplotlib\pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,..." width="639.9999861283738">
