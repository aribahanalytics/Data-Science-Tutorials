# %%
import numpy as np

# %%
a=np.array([1,2,3])

# %%
a

# %%
a.shape

# %%
a.size

# %%
a.ndim

# %%
a=np.array([[1,2,3],[4,5,6]])

# %%
a

# %%
a.shape

# %%
a.size

# %%
a.ndim

# %%
type(a)

# %%
x=np.arange(100)

# %%
x

# %%
x.shape=(20,5)

# %%
x

# %%
y=np.random.rand(5,80)
y

# %%
print(y.shape)
print(y.size)
print(y.ndim)

# %%
y.shape=(4, 20, -1)
print(y.shape)

# %%
y

# %%
x

# %%
x[2]

# %%
x[2:5]

# %%
list(range(5))

# %%
#first 5 rows
x[:5]

# %%
#from row 16 to end
x[16:]

# %%
#last 5 rows
x[-5:]

# %%
x[-6:]

# %%
#Boolean indexing
x[(x%2) == 0]

# %%
x[[1,3,4,6]]

# %%
#Broadcasting
print(x.shape)
print(y.shape)

# %%
y

# %%
a = x+y

# %%
a

# %%
print(a.shape)

# %%
import matplotlib
print(matplotlib.__version__)
print(matplotlib.get_backend())
# Out:
# 2.0.2
# module://ipykernel.pylab.backend_inline

# %%
matplotlib.use('nbagg')

# %%
import matplotlib.pyplot as plt

# %%
#figure
fig = plt.figure()

# %%
#display the plot
plt.show()

# %%
#control the size of the fig
fig=plt.figure(figsize=plt.figaspect(2.0))
plt.show()

# %%
fig=plt.figure()
#set the axis

ax=fig.add_subplot(111)
ax.set(xlim=[0.5,4.5],
       ylim=[-2,8],
       title='Example with axis',
       ylabel = 'Y-Axis',
       xlabel='X-Axis')

plt.show()

# %%
fig=plt.figure(figsize=plt.figaspect(2.0))
#set the axis

ax=fig.add_subplot(111)
ax.set(xlim=[0.5,4.5],
       ylim=[-2,8],
       title='Example with axis',
       ylabel = 'Y-Axis',
       xlabel='X-Axis')

plt.show()

# %%
fig=plt.figure()
ax1=fig.add_subplot(221)
ax2=fig.add_subplot(222)
ax3=fig.add_subplot(223)
ax4=fig.add_subplot(224)

plt.show()

# %%
fig=plt.figure()
ax=fig.add_subplot(111)
ax.plot([1,2,3,4], [10, 20, 25, 30], color='lightblue', linewidth=3)
ax.scatter([0.3, 3.8, 1.2, 2.5], [11, 25, 9, 26], color='darkgreen', marker = '^')
ax.set_xlim(0.5, 4.5)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig=plt.figure()
ax=fig.add_subplot(111)
ax.plot([1,2,3,4], [10, 20, 25, 30], color='lightblue', linewidth=3)
ax.scatter([0.3, 3.8, 1.2, 2.5], [11, 25, 9, 26], color='darkgreen', marker = '^')
ax.scatter([1.3, 2.8, 4.2, 3.5], [11, 25, 9, 26], color='red', marker = '^')

ax.set_xlim(0.5, 4.5)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#1-D
#2-D
#3-D

# %%
fig
ax

ax.plot()
ax.scatter()
ax.bar()
polygons / filled - stackplots

#2- D plots

#contour

# %%
plt.subplots(nrows=2, ncols=2)
# Out:
# (<matplotlib.figure.Figure at 0x2442add8fd0>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002442ADC1128>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002442B404208>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x000002442B44DBE0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002442B411668>]], dtype=object))

# %%
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.random.seed(1)
x=np.arange(5)
y=np.random.randn(5)

fig, axes = plt.subplots(ncols=2)

vert_bars=axes[0].bar(x,y,color='lightblue', align='center')
horiz_bars=axes[1].barh(x,y,color='lightblue', align='center')

axes[0].axhline(0, color='gray', linewidth=2)
axes[1].axvline(0, color='gray', linewidth=2)

# %%
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.random.seed(1)
y=np.random.randn(100).cumsum()
x=np.linspace(0, 10,100)

fig, ax=plt.subplots()
ax.fill_between(x, y, color='lightblue')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from matplotlib.cbook import get_sample_data

data=np.load(get_sample_data('axes_grid/bivariate_normal.npy'))

fig, ax=plt.subplots()
im=ax.imshow(data, cmap='seismic', interpolation='nearest')
fig.colorbar(im)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
