# %%
#Pandas

# %%
pip install pandas

# %%
import pandas as pd

# %%
#Series 
#DataFrames

# %%
import numpy as np

# %%
import (lib-name)

# %%
sum | sum

# %%
#creating dataframe from list/tuples

# %%
sales_list = [("Name1", 100, 150, 200), ('Name2', 200, 250, 300)]

# %%
type(sales_list)
# Out:
# list

# %%
labels=['Names', "Value1", "value2", 'value3']

# %%
df = pd.DataFrame.from_records(sales_list, columns= labels)

# %%
df
# Out:
#    Names  Value1  value2  value3
# 0  Name1     100     150     200
# 1  Name2     200     250     300

# %%
df['Names']
# Out:
# 0    Name1
# 1    Name2
# Name: Names, dtype: object

# %%
df[['Names', 'Value1']]
# Out:
#    Names  Value1
# 0  Name1     100
# 1  Name2     200

# %%
#creating dataframes from dictionary

# %%
sales_dict = {'Names': ["Name1", "Name2","Name3" ], 'Value1':[2,3,4]}

# %%
type(sales_dict)
# Out:
# dict

# %%
df_dict = pd.DataFrame.from_dict(sales_dict)

# %%
df_dict
# Out:
#    Names  Value1
# 0  Name1       2
# 1  Name2       3
# 2  Name3       4

# %%
df_dict[:1]
# Out:
#    Names  Value1
# 0  Name1       2

# %%
df_dict['Names']
# Out:
# 0    Name1
# 1    Name2
# 2    Name3
# Name: Names, dtype: object

# %%
df_dict[:1]
# Out:
#    Names  Value1
# 0  Name1       2

# %%
df_dict[:2]
# Out:
#    Names  Value1
# 0  Name1       2
# 1  Name2       3

# %%
pd.Series([0.25, 0.5, 0.75])
# Out:
# 0    0.25
# 1    0.50
# 2    0.75
# dtype: float64

# %%
df1=pd.Series([0.25, 0.5, 0.75])

# %%
type(df1)
# Out:
# pandas.core.series.Series

# %%
df2=df_dict['Names']
type(df2)
# Out:
# pandas.core.series.Series

# %%
type(df_dict)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.values
# Out:
# array([ 0.25,  0.5 ,  0.75])

# %%
df1.values
# Out:
# array([ 0.25,  0.5 ,  0.75])

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df1[1]
# Out:
# 0.5

# %%
df1[:2]
# Out:
# 0    0.25
# 1    0.50
# dtype: float64

# %%
df1[:3]
# Out:
# 0    0.25
# 1    0.50
# 2    0.75
# dtype: float64

# %%
#read csv files

# %%
data = pd.read_csv('Data/uk-500.csv')

# %%
#df = pd.read_csv('C:/Pandas/data/uk-500.csv')

# %%
data
# Out:
#        FirstName    LastName                         Company  \
# 0        Aleshia  Tomkiewicz         Alan D Rosenburg Cpa Pc
# 1           Evan   Zigomalas              Cap Gemini America
# 2         France     Andrade             Elliott, John W Esq
# 3        Ulysses   Mcwalters                  Mcmahan, Ben L
# 4         Tyisha      Veness                  Champagne Room
# 5           Eric       Rampy         Thompson, Michael C Esq
# 6           Marg    Grasmick   Wrangle Hill Auto Auct & Slvg
# 7        Laquita       Hisaw           In Communications Inc
# 8           Lura    Manzella                 Bizerba Usa Inc
# 9         Yuette      Klapec                       Max Video
# 10      Fernanda      Writer            K & R Associates Inc
# 11   Charlesetta         Erm                Cain, John M Esq
# 12      Corrinne       Jaret               Sound Vision Corp
# 13        Niesha       Bruch          Rowley/hansell Petetin
# ...

# %%
data.head()
# Out:
#   FirstName    LastName                  Company            Address  \
# 0   Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1      Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2    France     Andrade      Elliott, John W Esq       8 Moor Place
# 3   Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4    Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              City           County  PostCode    Telephone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#      Telephone2                       Email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# ...

# %%
import os
os.chdir('')

# %%
import os
print(os.getcwd())
# Out:
# C:\Pandas

# %%
data.columns
# Out:
# Index(['FirstName', 'LastName', 'Company', 'Address', 'City', 'County',
#        'PostCode', 'Telephone1', 'Telephone2', 'Email', 'Web'],
#       dtype='object')

# %%
import random

# %%
data['id'] = [random.randint(0, 1000) for x in range(data.shape[0])]

# %%
data.columns
# Out:
# Index(['FirstName', 'LastName', 'Company', 'Address', 'City', 'County',
#        'PostCode', 'Telephone1', 'Telephone2', 'Email', 'Web', 'id'],
#       dtype='object')

# %%
#Row indexing

# %%
data.iloc[0]
#data.loc
# Out:
# FirstName                                  Aleshia
# LastName                                Tomkiewicz
# Company                    Alan D Rosenburg Cpa Pc
# Address                               14 Taylor St
# City                             St. Stephens Ward
# County                                        Kent
# PostCode                                   CT2 7PP
# Telephone1                            01835-703597
# Telephone2                            01944-369967
# Email                      atomkiewicz@hotmail.com
# Web           http://www.alandrosenburgcpapc.co.uk
# id                                             918
# Name: 0, dtype: object

# %%
data.iloc[1]
# Out:
# FirstName                                  Evan
# LastName                              Zigomalas
# Company                      Cap Gemini America
# Address                             5 Binney St
# City                                 Abbey Ward
# County                          Buckinghamshire
# PostCode                               HP11 2AX
# Telephone1                         01937-864715
# Telephone2                         01714-737668
# Email                  evan.zigomalas@gmail.com
# Web           http://www.capgeminiamerica.co.uk
# id                                          108
# Name: 1, dtype: object

# %%
data.iloc[-1]
# Out:
# FirstName                                              Mi
# LastName                                           Richan
# Company                    Nelson Wright Haworth Golf Crs
# Address                                   6 Norwood Grove
# City                                    Tanworth-in-Arden
# County                                       Warwickshire
# PostCode                                          B94 5RZ
# Telephone1                                   01451-785624
# Telephone2                                   01202-738406
# Email                                      mi@hotmail.com
# Web           http://www.nelsonwrighthaworthgolfcrs.co.uk
# id                                                    738
# Name: 499, dtype: object

# %%
#column indexing

# %%
data.iloc[:, 0]
# Out:
# 0          Aleshia
# 1             Evan
# 2           France
# 3          Ulysses
# 4           Tyisha
# 5             Eric
# 6             Marg
# 7          Laquita
# 8             Lura
# 9           Yuette
# 10        Fernanda
# 11     Charlesetta
# 12        Corrinne
# 13          Niesha
# 14          Rueben
# 15         Michell
# 16           Edgar
# 17          Dewitt
# 18        Charisse
# 19             Mee
# 20           Peter
# 21         Octavio
# 22          Martha
# 23         Tamesha
# 24            Tess
# 25         Leonard
# 26        Svetlana
# 27             Pok
# 28       Augustine
# 29           Karma
#           ...
# 470           Tony
# 471            Val
# 472            Mel
# 473       Isabella
# 474         Erasmo
# 475          Ivory
# 476         Nikita
# 477          Aleta
# 478           Owen
# 479        Pauline
# 480        Tijuana
# 481          Ahmad
# 482         Jamika
# 483        Derrick
# 484     Jacquelyne
# 485        Zachary
# ...

# %%
data.iloc[:, 1]
# Out:
# 0      Tomkiewicz
# 1       Zigomalas
# 2         Andrade
# 3       Mcwalters
# 4          Veness
# 5           Rampy
# 6        Grasmick
# 7           Hisaw
# 8        Manzella
# 9          Klapec
# 10         Writer
# 11            Erm
# 12          Jaret
# 13          Bruch
# 14      Gastellum
# 15      Throssell
# 16          Kanne
# 17          Julio
# 18       Spinello
# 19       Lapinski
# 20      Gutierres
# 21      Salvadore
# 22        Teplica
# 23         Veigel
# 24          Sitra
# 25         Kufner
# 26         Tauras
# 27       Molaison
# 28       Growcock
# 29         Quarto
#           ...
# 470    Diazdeleon
# 471        Villot
# 472      Picciuto
# 473    Piatkowski
# 474          Rhea
# 475       Lohrenz
# 476         Walka
# 477        Ligons
# 478       Jentzen
# 479         Fling
# 480      Machalek
# 481       Alsaqri
# 482        Conoly
# 483       Dolloff
# 484       Reibman
# 485    Freeburger
# 486       Gaucher
# 487          Kono
# 488       Brigman
# ...

# %%
data.iloc[:, -1]
# Out:
# 0       918
# 1       108
# 2       462
# 3       503
# 4      1000
# 5       129
# 6       964
# 7       491
# 8       726
# 9       756
# 10      587
# 11      995
# 12      608
# 13      399
# 14      465
# 15      166
# 16      206
# 17      968
# 18      501
# 19      170
# 20      912
# 21      146
# 22      690
# 23      857
# 24      432
# 25      131
# 26      592
# 27      112
# 28      926
# 29      886
#        ...
# 470     787
# 471     686
# 472     259
# 473     309
# 474     331
# 475     450
# 476     380
# 477     836
# 478     708
# 479     867
# 480     588
# 481      11
# 482     650
# 483      83
# 484     507
# 485     937
# 486      23
# 487     363
# 488      90
# 489     291
# 490     458
# 491     643
# 492     347
# 493     676
# 494      60
# 495     481
# 496      64
# 497     539
# 498     301
# 499     738
# Name: id, Length: 500, dtype: int64

# %%
#multiple rows and columns
data.iloc[0:5]
# Out:
#   FirstName    LastName                  Company            Address  \
# 0   Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1      Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2    France     Andrade      Elliott, John W Esq       8 Moor Place
# 3   Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4    Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              City           County  PostCode    Telephone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#      Telephone2                       Email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# ...

# %%
data.iloc[:,1]
# Out:
# 0      Tomkiewicz
# 1       Zigomalas
# 2         Andrade
# 3       Mcwalters
# 4          Veness
# 5           Rampy
# 6        Grasmick
# 7           Hisaw
# 8        Manzella
# 9          Klapec
# 10         Writer
# 11            Erm
# 12          Jaret
# 13          Bruch
# 14      Gastellum
# 15      Throssell
# 16          Kanne
# 17          Julio
# 18       Spinello
# 19       Lapinski
# 20      Gutierres
# 21      Salvadore
# 22        Teplica
# 23         Veigel
# 24          Sitra
# 25         Kufner
# 26         Tauras
# 27       Molaison
# 28       Growcock
# 29         Quarto
#           ...
# 470    Diazdeleon
# 471        Villot
# 472      Picciuto
# 473    Piatkowski
# 474          Rhea
# 475       Lohrenz
# 476         Walka
# 477        Ligons
# 478       Jentzen
# 479         Fling
# 480      Machalek
# 481       Alsaqri
# 482        Conoly
# 483       Dolloff
# 484       Reibman
# 485    Freeburger
# 486       Gaucher
# 487          Kono
# 488       Brigman
# ...

# %%
data.iloc[:,0:2]
# Out:
#        FirstName    LastName
# 0        Aleshia  Tomkiewicz
# 1           Evan   Zigomalas
# 2         France     Andrade
# 3        Ulysses   Mcwalters
# 4         Tyisha      Veness
# 5           Eric       Rampy
# 6           Marg    Grasmick
# 7        Laquita       Hisaw
# 8           Lura    Manzella
# 9         Yuette      Klapec
# 10      Fernanda      Writer
# 11   Charlesetta         Erm
# 12      Corrinne       Jaret
# 13        Niesha       Bruch
# 14        Rueben   Gastellum
# 15       Michell   Throssell
# 16         Edgar       Kanne
# 17        Dewitt       Julio
# 18      Charisse    Spinello
# 19           Mee    Lapinski
# 20         Peter   Gutierres
# 21       Octavio   Salvadore
# 22        Martha     Teplica
# 23       Tamesha      Veigel
# 24          Tess       Sitra
# 25       Leonard      Kufner
# 26      Svetlana      Tauras
# 27           Pok    Molaison
# 28     Augustine    Growcock
# 29         Karma      Quarto
# ..           ...         ...
# ...

# %%
data.iloc[:,3:5]
# Out:
#                     Address                            City
# 0              14 Taylor St               St. Stephens Ward
# 1               5 Binney St                      Abbey Ward
# 2              8 Moor Place  East Southbourne and Tuckton W
# 3             505 Exeter Rd              Hawerby cum Beesby
# 4         5396 Forth Street      Greets Green and Lyng Ward
# 5              9472 Lind St                      Desborough
# 6          7457 Cowl St #70                    Bargate Ward
# 7      20 Gloucester Pl #96                    Chirton Ward
# 8          929 Augustine St                Staple Hill Ward
# 9      45 Bradfield St #166                         Parwich
# 10       620 Northampton St                      Wilmington
# 11              5 Hygeia St            Loundsley Green Ward
# 12           2150 Morley St                        Dee Ward
# 13             24 Bolton St  Broxburn, Uphall and Winchburg
# 14             4 Forrest St               Weston-Super-Mare
# ...

# %%
#Indexing multiple rows and multiple columns

# %%
new = data.iloc[[0,3,4], [0,5,3]]

# %%
new
# Out:
#   FirstName         County            Address
# 0   Aleshia           Kent       14 Taylor St
# 3   Ulysses   Lincolnshire      505 Exeter Rd
# 4    Tyisha  West Midlands  5396 Forth Street

# %%
data.iloc[0:4, 0:5]
# Out:
#   FirstName    LastName                  Company        Address  \
# 0   Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc   14 Taylor St
# 1      Evan   Zigomalas       Cap Gemini America    5 Binney St
# 2    France     Andrade      Elliott, John W Esq   8 Moor Place
# 3   Ulysses   Mcwalters           Mcmahan, Ben L  505 Exeter Rd
#
#                              City
# 0               St. Stephens Ward
# 1                      Abbey Ward
# 2  East Southbourne and Tuckton W
# 3              Hawerby cum Beesby

# %%
random.randint(0, 1000)
# Out:
# 841

# %%
random.randint(0, 1000)
# Out:
# 388

# %%
data = pd.read_csv()
data.shape[0]
# Out:
# (500, 12)

# %%
data.shape[0]
# Out:
# 500

# %%
data.shape[1]
# Out:
# 12

# %%
data.shape[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-79-729b767e172a> in <module>()
# ----> 1 data.shape[3]
#
# IndexError: tuple index out of range

# %%
random.randint(0, 1000)
# Out:
# 278

# %%
data['new_col']=[ifelse(data['Address'] == "T", 1, 0)]
